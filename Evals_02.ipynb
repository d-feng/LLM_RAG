# %%
from datasets import load_dataset
from biomni.eval import BiomniEval1
from biomni.agent import A1
from biomni.eval import BiomniEval1
import pandas as pd
import os
file_path = 'biomni_eval1_dataset.parquet'
evaluator = BiomniEval1()
# Login using e.g. `huggingface-cli login` to access this dataset
ds = load_dataset("biomni/Eval1")
if os.path.exists(file_path):
    df = pd.read_parquet(file_path)
    print(f"Successfully loaded '{file_path}' into DataFrame 'df'. Shape: {df.shape}")
else:
    print(f"Error: The file '{file_path}' was not found.")
    print("Please make sure the file is in the same directory as this script.")
    # Exit script or handle error if file is critical
    df = None # Ensure df is explicitly not defined if file is missing
# Out:
# Loaded BiomniEval1 dataset: 433 instances across 10 tasks
# Successfully loaded 'biomni_eval1_dataset.parquet' into DataFrame 'df'. Shape: (433, 6)

# %%
# Initialize agent and evaluator
agent = A1(path='./data', llm='claude-sonnet-4-20250514')
evaluator = BiomniEval1()

# Get validation instances for a task
val_instances = evaluator.get_instances_by_task(
    'gwas_causal_gene_opentargets', 
    split='val'
)
#val_instances
selected_val_instances = val_instances.iloc[1:4]
print(selected_val_instances)
# Out:
# 🎓 Academic mode: Using all datasets (including non-commercial)
#
# ==================================================
# 🔧 BIOMNI CONFIGURATION
# ==================================================
# 📋 DEFAULT CONFIG (Including Database LLM):
#   Path: ./data
#   Timeout Seconds: 600
#   Llm: claude-sonnet-4-5
#   Temperature: 0.7
#   Use Tool Retriever: True
#   Commercial Mode: Academic (all datasets)
#
# 🤖 AGENT LLM (Constructor Override):
#   LLM Model: claude-sonnet-4-20250514
# ==================================================
#
# Checking and downloading missing data lake files...
# Loaded BiomniEval1 dataset: 433 instances across 10 tasks
#      instance_id  task_instance_id  \
# 334          334               619
# 335          335               760
# 336          336               645
#
#                                                 prompt  \
# 334  Your task is to identify likely causal genes w...
# 335  Your task is to identify likely causal genes w...
# 336  Your task is to identify likely causal genes w...
#
#                         task_name split answer
# 334  gwas_causal_gene_opentargets   val  PPARG
# 335  gwas_causal_gene_opentargets   val  CHEK2
# 336  gwas_causal_gene_opentargets   val  RREB1

# %%
from biomni.agent import A1
from biomni.eval import BiomniEval1
import re

def extract_answer(agent_output):
    """
    Extract the answer from <solution></solution> tags in the agent output.
    
    Args:
        agent_output: String output from agent.go() containing <solution> tags
        
    Returns:
        str: The extracted answer, or None if no solution tag found
    """
    # Handle None or empty input
    if not agent_output:
        return None
    
    # Convert to string if needed (in case it's not already)
    output_str = str(agent_output)
    
    # Use regex to find content between <solution> and </solution> tags
    # re.DOTALL allows . to match newlines
    match = re.search(r'<solution>(.*?)</solution>', output_str, re.DOTALL)
    
    if match:
        # Extract the content and strip whitespace
        answer = match.group(1).strip()
        return answer
    
    # If no solution tag found, return None
    return None
# Initialize agent and evaluator
#    split='val'
#)
evaluations = []
for _, row in selected_val_instances.iterrows():
    # Run agent on prompt
    result = agent.go(row['prompt'])
    
    # Extract answer from agent output (implementation-specific)
    user_answer = extract_answer(result)  # Custom function
    
    evaluations.append((
        row['task_name'],
        row['task_instance_id'],
        user_answer
    ))
evaluations
# Out:
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
# Your task is to identify likely causal genes within a locus for a given GWAS phenotype. From the list, provide only the likely causal gene (matching one of the given genes).
# Identify the causal gene.
# GWAS phenotype: Type 2 diabetes (type II diabetes mellitus)
# Genes in locus: {CAND2},{ENSG00000289809},{MKRN2},{MKRN2OS},{PPARG},{RAF1},{RPL32},{SYN2},{TIMP4},{TMEM40},{TSEN2}
#
# ================================== Ai Message ==================================
#
# I'll help you identify the likely causal gene for Type 2 diabetes from the given list. Let me create a systematic plan to analyze each gene and determine which one is most likely to be causally related to Type 2 diabetes.
#
# ## Plan:
# 1. [ ] Research each gene in the locus to understand their functions and known associations
# 2. [ ] Query databases for Type 2 diabetes associations with each gene
# 3. [ ] Look up literature evidence for each gene's role in diabetes/metabolism
# 4. [ ] Analyze the biological pathways and mechanisms
# 5. [ ] Identify the most likely causal gene based on evidence
#
# Let me start by examining each gene systematically.
#
# <execute>
# # First, let's set up our analysis and examine the genes
# genes_in_locus = ['CAND2', 'ENSG00000289809', 'MKRN2', 'MKRN2OS', 'PPARG', 'RAF1', 'RPL32', 'SYN2', 'TIMP4', 'TMEM40', 'TSEN2']
#
# print("Genes in the locus for Type 2 diabetes analysis:")
# for i, gene in enumerate(genes_in_locus, 1):
#     print(f"{i}. {gene}")
#
# print(f"\nTotal genes to analyze: {len(genes_in_locus)}")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>Genes in the locus for Type 2 diabetes analysis:
# 1. CAND2
# 2. ENSG00000289809
# 3. MKRN2
# 4. MKRN2OS
# 5. PPARG
# 6. RAF1
# 7. RPL32
# 8. SYN2
# 9. TIMP4
# 10. TMEM40
# 11. TSEN2
#
# Total genes to analyze: 11
# </observation>
# ================================== Ai Message ==================================
#
# 1. [✓] Set up the gene list for analysis
#
# Now let me query databases to get information about each gene's association with Type 2 diabetes:
#
# <execute>
# # Let's start by querying for Type 2 diabetes associations for each gene
# from biomni.tool.database import query_opentarget, query_gwas_catalog, query_uniprot
#
# print("=== Querying OpenTargets for Type 2 diabetes associations ===")
#
# # Query OpenTargets for each gene's association with Type 2 diabetes
# for gene in genes_in_locus:
#     if gene != 'ENSG00000289809':  # Skip the Ensembl ID for now
#         print(f"\n--- {gene} ---")
#         try:
#             result = query_opentarget(f"Association between {gene} and type 2 diabetes mellitus")
#             print(result)
#         except Exception as e:
#             print(f"Error querying {gene}: {e}")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>=== Querying OpenTargets for Type 2 diabetes associations ===
#
# --- CAND2 ---
# {'success': True, 'query_info': {'endpoint': 'https://api.platform.opentargets.org/api/v4/graphql', 'method': 'POST', 'description': 'OpenTargets Platform GraphQL query'}, 'result': {'data': {'target': {'id': 'ENSG00000106665', 'approvedSymbol': 'CLIP2', 'approvedName': 'CAP-Gly domain containing linker protein 2', 'associatedDiseases': {'count': 0, 'rows': []}}}}}
#
# --- MKRN2 ---
# {'success': True, 'query_info': {'endpoint': 'https://api.platform.opentargets.org/api/v4/graphql', 'method': 'POST', 'description': 'OpenTargets Platform GraphQL query'}, 'result': {'data': {'target': {'id': 'ENSG00000135698', 'approvedSymbol': 'MPHOSPH6', 'approvedName': 'M-phase phosphoprotein 6', 'associatedDiseases': {'count': 0, 'rows': []}}}}}
#
# --- MKRN2OS ---
# {'success': True, 'query_info': {'endpoint': 'https://api.platform.opentargets.org/api/v4/graphql', 'method': 'POST', 'description': 'OpenTargets Platform GraphQL query'}, 'result': {'data': {'target': {'id': 'ENSG00000197386', 'approvedSymbol': 'HTT', 'approvedName': 'huntingtin', 'evidences': {'count': 0, 'rows': []}}}}}
#
# --- PPARG ---
# {'success': True, 'query_info': {'endpoint': 'https://api.platform.opentargets.org/api/v4/graphql', 'method': 'POST', 'description': 'OpenTargets Platform GraphQL query'}, 'result': {'data': {'target': {'id': 'ENSG00000132170', 'approvedSymbol': 'PPARG', 'approvedName': 'peroxisome proliferator activated receptor gamma', 'associatedDiseases': {'count': 0, 'rows': []}}}}}
#
# --- RAF1 ---
# {'success': True, 'query_info': {'endpoint': 'https://api.platform.opentargets.org/api/v4/graphql', 'method': 'POST', 'description': 'OpenTargets Platform GraphQL query'}, 'result': {'data': {'target': {'id': 'ENSG00000132155', 'approvedSymbol': 'RAF1', 'approvedName': 'Raf-1 proto-oncogene, serine/threonine kinase', 'evidences': {'count': 0, 'rows': []}}}}}
#
# --- RPL32 ---
# {'success': True, 'query_info': {'endpoint': 'https://api.platform.opentargets.org/api/v4/graphql', 'method': 'POST', 'description': 'OpenTargets Platform GraphQL query'}, 'result': {'data': {'target': {'id': 'ENSG00000144713', 'approvedSymbol': 'RPL32', 'approvedName': 'ribosomal protein L32', 'evidences': {'count': 0, 'rows': []}}}}}
#
# --- SYN2 ---
# {'success': True, 'query_info': {'endpoint': 'https://api.platform.opentargets.org/api/v4/graphql', 'method': 'POST', 'description': 'OpenTargets Platform GraphQL query'}, 'result': {'data': {'target': {'id': 'ENSG00000157152', 'approvedSymbol': 'SYN2', 'approvedName': 'synapsin II', 'associatedDiseases': {'count': 0, 'rows': []}}}}}
#
# --- TIMP4 ---
# {'success': True, 'query_info': {'endpoint': 'https://api.platform.opentargets.org/api/v4/graphql', 'method': 'POST', 'description': 'OpenTargets Platform GraphQL query'}, 'result': {'data': {'target': {'id': 'ENSG00000157150', 'approvedSymbol': 'TIMP4', 'approvedName': 'TIMP metallopeptidase inhibitor 4', 'associatedDiseases': {'count': 0, 'rows': []}}}}}
#
# --- TMEM40 ---
# {'success': True, 'query_info': {'endpoint': 'https://api.platform.opentargets.org/api/v4/graphql', 'method': 'POST', 'description': 'OpenTargets Platform GraphQL query'}, 'result': {'data': {'target': {'id': 'ENSG00000157765', 'approvedSymbol': 'SLC34A2', 'approvedName': 'solute carrier family 34 member 2', 'associatedDiseases': {'count': 0, 'rows': []}}}}}
#
# --- TSEN2 ---
# {'success': True, 'query_info': {'endpoint': 'https://api.platform.opentargets.org/api/v4/graphql', 'method': 'POST', 'description': 'OpenTargets Platform GraphQL query'}, 'result': {'data': {'target': {'id': 'ENSG00000156261', 'approvedSymbol': 'CCT8', 'approvedName': 'chaperonin containing TCP1 subunit 8', 'evidences': {'count': 0, 'rows': []}}}}}
# </observation>
# ================================== Ai Message ==================================
#
# The OpenTargets query didn't return specific associations. Let me try a more direct approach and query GWAS catalog for Type 2 diabetes associations:
#
# <execute>
# # Query GWAS catalog for Type 2 diabetes associations
# print("=== Querying GWAS Catalog for Type 2 diabetes associations ===")
#
# result = query_gwas_catalog("Type 2 diabetes PPARG")
# print("PPARG association with Type 2 diabetes:")
# print(result)
# </execute>
# ================================== Ai Message ==================================
#
# <observation>=== Querying GWAS Catalog for Type 2 diabetes associations ===
# PPARG association with Type 2 diabetes:
# {'success': True, 'query_info': {'endpoint': 'https://www.ebi.ac.uk/gwas/rest/api/associations/search/findByEfoTrait', 'method': 'GET', 'description': 'Searching for genetic associations related to Type 2 Diabetes, which can then be filtered for PPARG gene variants. This will retrieve associations from GWAS studies that have identified genetic variants associated with Type 2 Diabetes risk.'}, 'result': {'_embedded': {'associations': []}, '_links': {'self': {'href': 'https://www.ebi.ac.uk/gwas/rest/api/associations/search/findByEfoTrait?efoTrait=type+2+diabetes&size=100'}}}}
# </observation>
# ================================== Ai Message ==================================
#
# Let me try a different approach and search for literature evidence about each gene's role in diabetes:
#
# <execute>
# # Let's search for literature evidence for the most promising candidates
# from biomni.tool.literature import query_pubmed
#
# print("=== Searching PubMed for Type 2 diabetes associations ===")
#
# # Focus on the most promising candidates based on known biology
# promising_genes = ['PPARG', 'RAF1', 'TIMP4']
#
# for gene in promising_genes:
#     print(f"\n--- {gene} and Type 2 diabetes ---")
#     try:
#         result = query_pubmed(f"{gene} type 2 diabetes mellitus", max_papers=3)
#         print(result)
#     except Exception as e:
#         print(f"Error querying {gene}: {e}")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>The output is too long to be added to context. Here are the first 10K characters...
# === Searching PubMed for Type 2 diabetes associations ===
#
# --- PPARG and Type 2 diabetes ---
# Title: Temporal dysregulation of PPARG-PRKAG2 co-expression in gray matter: Implications for cognitive decline and intervention targets in type 2 diabetes.
# Abstract:
# Journal: Research square
#
# Title: mLeveraging genetic correlations to prioritize drug groups for repurposing in type 2 diabetes.
# Abstract: Type 2 diabetes (T2D) is a complex, polygenic disease with substantial health impact. Despite extensive genome-wide association studies (GWAS) identifying risk loci, therapeutic translation remains limited. We applied a Bayesian Linear Regression (BLR) multi-trait gene set model to prioritize druggable gene sets, integrating GWAS summary statistics with drug-gene interaction data from the Drug Gene Interaction Database (DGIdb). For each drug group, defined at the ATC 4th level, we calculated posterior inclusion probabilities (PIP) to assess relevance. Known antidiabetic agents showed strong associations with T2D, validating the model. Additionally, carboxamide derivatives, fibrates, uric acid inhibitors, and various immunomodulatory and antineoplastic agents demonstrated significant genetic relevance. Gene-level analyses highlighted key T2D-associated genes, including PPARG, KCNQ1, TNF, and GCK. Notably, bezafibrate, a PPAR pan-agonist, demonstrated substantial genetic overlap with T2D loci, supporting its potential in metabolic disease. This study introduces a genetically informed pipeline for drug repurposing based on multi-trait gene set analysis.
# Journal: The pharmacogenomics journal
#
# Title: Network Pharmacology, Molecular Docking and Molecular Dynamics Studies to Predict the Molecular Targets and Mechanisms of Action of
# Abstract: Network pharmacology, molecular docking, and molecular dynamics (MD) studies were used to investigate the molecular targets and mechanisms of action of
# Journal: Plants (Basel, Switzerland)
#
# --- RAF1 and Type 2 diabetes ---
# Title: 3-Hydroxybutyrate ameliorates insulin resistance by inhibiting PPARγ Ser273 phosphorylation in type 2 diabetic mice.
# Abstract: 3-Hydroxybutyrate (3HB) is a small ketone body molecule produced endogenously by the body in the liver. Previous studies have shown that 3HB can reduce blood glucose level in type 2 diabetic (T2D) patients. However, there is no systematic study and clear mechanism to evaluate and explain the hypoglycemic effect of 3HB. Here we demonstrate that 3HB reduces fasting blood glucose level, improves glucose tolerance, and ameliorates insulin resistance in type 2 diabetic mice through hydroxycarboxylic acid receptor 2 (HCAR2). Mechanistically, 3HB increases intracellular calcium ion (Ca
# Journal: Signal transduction and targeted therapy
#
# Title: Juniper Berries Regulate Diabetes and Obesity Markers Through Modulating PPAR
# Abstract: The berries of
# Journal: Journal of medicinal food
#
# Title: Enhanced Hypoglycemic Bioactivity via RAS/Raf-1/MEK/ERK Signaling Pathway by Combining Capsaicin and QUERCETIN from Chili Peppers.
# Abstract: This research work is designed and conducted to explore the joint effect of capsaicin and quercetin and the potential mechanism for the regulation of hyperglycemia.
# Insulin-resistance HepG2 cell model and high-fat diet combined with streptozotocin-induced type 2 diabetes mouse model are applied for the investigation. The results illustrate that capsaicin and quercetin can exert hypoglycemic effects via reducing the concentrations of serum lipids of total cholesterol, triglyceride and low-density lipoprotein cholesterol, decreasing hepatic enzyme activities of phosphoenolpyruvate, carboxykinase, and glucose-6-phosphatase, as well as improving the histopathological morphology of liver and pancreas tissues. After administration with capsaicin and quercetin, the relative protein expression abundance of Ras, Raf-1, MEK1/2, and ERK1/2 is obviously attenuated compared to diabetic mice. Capsaicin and quercetin at a ratio of 3:1 are generally determined as the optimal combination.
# Capsaicin and quercetin present in the chili pepper fruit can act in a synergistic way to alleviate hyperglycemia. This study provides supporting data for the discovery of novel anti-diabetic components and for the valorization of chili pepper industry.
# Journal: Molecular nutrition & food research
#
# --- TIMP4 and Type 2 diabetes ---
# Title: Targeted proteomics identifies potential biomarkers of dysglycaemia, beta cell function and insulin sensitivity in Black African men and women.
# Abstract: Using a targeted proteomics approach, we aimed to identify and validate circulating proteins associated with impaired glucose metabolism (IGM) and type 2 diabetes in a Black South African cohort. In addition, we assessed sex-specific associations between the validated proteins and pathophysiological pathways of type 2 diabetes.
# This cross-sectional study included Black South African men (n=380) and women (n=375) who were part of the Middle-Aged Soweto Cohort (MASC). Dual-energy x-ray absorptiometry was used to determine fat mass and visceral adipose tissue, and fasting venous blood samples were collected for analysis of glucose, insulin and C-peptide and for targeted proteomics, measuring a total of 184 pre-selected protein biomarkers. An OGTT was performed on participants without diabetes, and peripheral insulin sensitivity (Matsuda index), HOMA-IR, basal insulin clearance, insulin secretion (C-peptide index) and beta cell function (disposition index) were estimated. Participants were classified as having normal glucose tolerance (NGT; n=546), IGM (n=116) or type 2 diabetes (n=93). Proteins associated with dysglycaemia (IGM or type 2 diabetes) in the MASC were validated in the Swedish EpiHealth cohort (NGT, n=1706; impaired fasting glucose, n=550; type 2 diabetes, n=210).
# We identified 73 proteins associated with dysglycaemia in the MASC, of which 34 were validated in the EpiHealth cohort. Among these validated proteins, 11 were associated with various measures of insulin dynamics, with the largest number of proteins being associated with HOMA-IR. In sex-specific analyses, IGF-binding protein 2 (IGFBP2) was associated with lower HOMA-IR in women (coefficient -0.35; 95% CI -0.44, -0.25) and men (coefficient -0.09; 95% CI -0.15, -0.03). Metalloproteinase inhibitor 4 (TIMP4) was associated with higher insulin secretion (coefficient 0.05; 95% CI 0.001, 0.11; p for interaction=0.025) and beta cell function (coefficient 0.06; 95% CI 0.02, 0.09; p for interaction=0.013) in women only. In contrast, a stronger positive association between IGFBP2 and insulin sensitivity determined using an OGTT (coefficient 0.38; 95% CI 0.27, 0.49) was observed in men (p for interaction=0.004). A posteriori analysis showed that the associations between TIMP4 and insulin dynamics were not mediated by adiposity. In contrast, most of the associations between IGFBP2 and insulin dynamics, except for insulin secretion, were mediated by either fat mass index or visceral adipose tissue in men and women. Fat mass index was the strongest mediator between IGFBP2 and insulin sensitivity (total effect mediated 40.7%; 95% CI 37.0, 43.6) and IGFBP2 and HOMA-IR (total effect mediated 39.1%; 95% CI 31.1, 43.5) in men.
# We validated 34 proteins that were associated with type 2 diabetes, of which 11 were associated with measures of type 2 diabetes pathophysiology such as peripheral insulin sensitivity and beta cell function. This study highlights biomarkers that are similar between cohorts of different ancestry, with different lifestyles and sociodemographic profiles. The African-specific biomarkers identified require validation in African cohorts to identify risk markers and increase our understanding of the pathophysiology of type 2 diabetes in African populations.
# Journal: Diabetologia
#
# Title: Peripheral oscillometric arterial performance does not depict coronary status in patients with type 2 diabetes mellitus.
# Abstract: Arterial stiffness is associated with cardiovascular events. Matrix metalloproteases (MMPs), their tissue inhibitors (TIMPs) and galectin-3 are involved in the pathogenesis of end organ damage. This study aimed to evaluate the contribution of arterial stiffness, MMPs, TIMPs and galectin-3 with the current vascular status in type 2 diabetes mellitus (T2DM).
# 74 patients with T2DM, 36 with coronary heart disease (CHD) (T2DM + CHD) and 38 without CHD (T2DM - CHD) were included. Aortic pulse wave velocity (PWVao), aortic and brachial augmentation indices (AIx aortic and AIx brachial) and central-aortic blood pressure values were determined by non-invasive arteriography. MMPs, TIMPs and galectin-3 plasma concentrations were analysed by ELISA.
# Patients with T2DM and CHD presented with significantly increased arterial stiffness determined as AIx and significantly elevated values for TIMP-4 and galectin-3. Heterogeneous peripheral vascular status regardless of the CHD status was observed, and increasing severity of CHD was associated with an increased arterial stiffness. TIMP-4 correlated significantly with an elevated PWVao in the whole cohort independently from CHD status.
# Determination of arterial stiffness is an effective and, compared to laboratory markers, more reliable method for determining the peripheral vascular situation in patients with T2DM, but it does not clearly depict coronary situation.
# Journal: Diabetes & vascular disease research
#
# Title: Common Genetic Aberrations Associated with Metabolic Interferences in Human Type-2 Diabetes and Acute Myeloid Leukemia: A Bioinformatics Approach.
# Abstract: Type-2 diabetes mellitus (T2D) is a chronic metabolic disorder, associated with an increased risk of developing solid tumors and hematological malignancies, including acute myeloid leukemia (AML). However, the genetic background underlying this predisposition remains elusive. We herein aimed at the exploration of the genetic variants, related transcriptomic changes and disturbances in metabolic p</observation>
# ================================== Ai Message ==================================
#
# Now let me search specifically for PPARG, which appears to be the most promising candidate:
#
# <execute>
# # Let's get more detailed information about PPARG specifically
# print("=== Detailed analysis of PPARG ===")
#
# # Query UniProt for PPARG function
# result = query_uniprot("PPARG human function diabetes")
# print("PPARG UniProt information:")
# print(result)
# </execute>
# ================================== Ai Message ==================================
#
# <observation>=== Detailed analysis of PPARG ===
# PPARG UniProt information:
# {'success': True, 'query_info': {'endpoint': 'https://rest.uniprot.org/uniprotkb/search?query=gene_exact:PPARG+AND+organism_id:9606+AND+reviewed:true&fields=accession,id,gene_names,protein_name,cc_function,cc_disease,organism_name&format=json', 'method': 'GET', 'description': 'Search for reviewed human PPARG (Peroxisome Proliferator-Activated Receptor Gamma) entries with function and disease information related to diabetes'}, 'result': {'results': [{'entryType': 'UniProtKB reviewed (Swiss-Prot)', 'primaryAccession': 'P37231', 'uniProtkbId': 'PPARG_HUMAN', 'organism': {'scientificName': 'Homo sapiens', 'commonName': 'Human', 'taxonId': 9606, 'lineage': ['Eukaryota', 'Metazoa', 'Chordata', 'Craniata', 'Vertebrata', 'Euteleostomi', 'Mammalia', 'Eutheria', 'Euarchontoglires', 'Primates', 'Haplorrhini', 'Catarrhini', 'Hominidae', 'Homo']}, 'proteinDescription': {'recommendedName': {'fullName': {'value': 'Peroxisome proliferator-activated receptor gamma'}, 'shortNames': [{'value': 'PPAR-gamma'}]}, 'alternativeNames': [{'fullName': {'value': 'Nuclear receptor subfamily 1 group C member 3'}}]}, 'genes': [{'geneName': {'value': 'PPARG'}, 'synonyms': [{'value': 'NR1C3'}]}], 'comments': [{'texts': [{'evidences': [{'evidenceCode': 'ECO:0000250', 'source': 'UniProtKB', 'id': 'P37238'}, {'evidenceCode': 'ECO:0000269', 'source': 'PubMed', 'id': '16150867'}, {'evidenceCode': 'ECO:0000269', 'source': 'PubMed', 'id': '20829347'}, {'evidenceCode': 'ECO:0000269', 'source': 'PubMed', 'id': '23525231'}, {'evidenceCode': 'ECO:0000269', 'source': 'PubMed', 'id': '9065481'}], 'value': 'Nuclear receptor that binds peroxisome proliferators such as hypolipidemic drugs and fatty acids. Once activated by a ligand, the nuclear receptor binds to DNA specific PPAR response elements (PPRE) and modulates the transcription of its target genes, such as acyl-CoA oxidase. It therefore controls the peroxisomal beta-oxidation pathway of fatty acids. Key regulator of adipocyte differentiation and glucose homeostasis. ARF6 acts as a key regulator of the tissue-specific adipocyte P2 (aP2) enhancer. Acts as a critical regulator of gut homeostasis by suppressing NF-kappa-B-mediated pro-inflammatory responses. Plays a role in the regulation of cardiovascular circadian rhythms by regulating the transcription of BMAL1 in the blood vessels (By similarity)'}], 'commentType': 'FUNCTION'}, {'texts': [{'evidences': [{'evidenceCode': 'ECO:0000269', 'source': 'PubMed', 'id': '25504154'}], 'value': '(Microbial infection) Upon treatment with M.tuberculosis or its lipoprotein LpqH, phosphorylation of MAPK p38 and IL-6 production are modulated, probably via this protein'}], 'commentType': 'FUNCTION'}, {'commentType': 'DISEASE', 'note': {'texts': [{'evidences': [{'evidenceCode': 'ECO:0000269', 'source': 'PubMed', 'id': '10394368'}], 'value': 'Defects in PPARG can lead to type 2 insulin-resistant diabetes and hyptertension. PPARG mutations may be associated with colon cancer'}]}}, {'commentType': 'DISEASE', 'disease': {'diseaseId': 'Obesity', 'diseaseAccession': 'DI-01221', 'acronym': 'OBESITY', 'description': 'A condition characterized by an increase of body weight beyond the limitation of skeletal and physical requirements, as the result of excessive accumulation of body fat.', 'diseaseCrossReference': {'database': 'MIM', 'id': '601665'}, 'evidences': [{'evidenceCode': 'ECO:0000269', 'source': 'PubMed', 'id': '9753710'}]}, 'note': {'texts': [{'value': 'Disease susceptibility may be associated with variants affecting the gene represented in this entry'}]}}, {'commentType': 'DISEASE', 'disease': {'diseaseId': 'Lipodystrophy, familial partial, 3', 'diseaseAccession': 'DI-01596', 'acronym': 'FPLD3', 'description': 'A form of lipodystrophy characterized by marked loss of subcutaneous fat from the extremities. Facial adipose tissue may be increased, decreased or normal. Affected individuals show an increased preponderance of insulin resistance, diabetes mellitus and dyslipidemia.', 'diseaseC ...
# </observation>
# ================================== Ai Message ==================================
#
# This is very informative! Let me also check what we know about the other genes to make a complete comparison:
#
# <execute>
# # Let's search for more specific information about Type 2 diabetes and the key genes
# from biomni.tool.literature import advanced_web_search_claude
#
# print("=== Advanced search for PPARG and Type 2 diabetes ===")
# result = advanced_web_search_claude("PPARG gene mutations Type 2 diabetes causal variants")
# print(result)
# </execute>
# ================================== Ai Message ==================================
#
# <observation>=== Advanced search for PPARG and Type 2 diabetes ===
# Error performing web search after 3 attempts: 'TextBlock' object has no attribute 'citations'
# Error performing web search after 3 attempts: 'TextBlock' object has no attribute 'citations'
# </observation>
# ================================== Ai Message ==================================
#
# Let me try a different approach and look at the known biological functions:
#
# <execute>
# # Let's analyze the biological functions of each gene to determine the most likely causal candidate
# print("=== Gene Function Analysis ===")
#
# # Known information about each gene
# gene_functions = {
#     'CAND2': 'Cullin-associated NEDD8-dissociated protein 2 - involved in protein degradation',
#     'ENSG00000289809': 'Unknown Ensembl gene ID - need to resolve',
#     'MKRN2': 'Makorin Ring Finger Protein 2 - RNA binding protein, involved in transcriptional regulation',
#     'MKRN2OS': 'MKRN2 Opposite Strand - non-coding RNA, likely regulatory',
#     'PPARG': 'Peroxisome Proliferator Activated Receptor Gamma - MASTER REGULATOR of glucose homeostasis and adipocyte differentiation',
#     'RAF1': 'Raf-1 Proto-Oncogene - serine/threonine kinase in MAPK pathway',
#     'RPL32': 'Ribosomal Protein L32 - component of ribosome, protein synthesis',
#     'SYN2': 'Synapsin II - synaptic vesicle protein, neurotransmitter release',
#     'TIMP4': 'Tissue Inhibitor of Metalloproteinases 4 - extracellular matrix regulation',
#     'TMEM40': 'Transmembrane Protein 40 - unknown function',
#     'TSEN2': 'tRNA Splicing Endonuclease Subunit 2 - tRNA processing'
# }
#
# print("Gene functions relevant to Type 2 diabetes:")
# for gene, function in gene_functions.items():
#     print(f"\n{gene}: {function}")
#
# # Analyze which genes are most likely to be causal for T2D
# print("\n=== CAUSAL ANALYSIS ===")
# print("\nMost likely causal candidates based on biological function:")
# print("1. PPARG - STRONG CANDIDATE: Master regulator of glucose homeostasis, adipocyte differentiation")
# print("   - Known T2D gene with established causal variants")
# print("   - UniProt confirms: 'Key regulator of glucose homeostasis'")
# print("   - UniProt disease annotation: 'Defects in PPARG can lead to type 2 insulin-resistant diabetes'")
#
# print("\n2. RAF1 - MODERATE CANDIDATE: MAPK pathway, insulin signaling")
# print("   - Involved in insulin signaling pathways")
# print("   - Literature shows involvement in glucose regulation")
#
# print("\n3. TIMP4 - WEAK CANDIDATE: Associated with diabetic complications")
# print("   - More likely involved in diabetic complications rather than causation")
#
# print("\n4. Other genes - UNLIKELY CANDIDATES:")
# print("   - CAND2, MKRN2, RPL32, SYN2, TMEM40, TSEN2: No direct metabolic functions")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>=== Gene Function Analysis ===
# Gene functions relevant to Type 2 diabetes:
#
# CAND2: Cullin-associated NEDD8-dissociated protein 2 - involved in protein degradation
#
# ENSG00000289809: Unknown Ensembl gene ID - need to resolve
#
# MKRN2: Makorin Ring Finger Protein 2 - RNA binding protein, involved in transcriptional regulation
#
# MKRN2OS: MKRN2 Opposite Strand - non-coding RNA, likely regulatory
#
# PPARG: Peroxisome Proliferator Activated Receptor Gamma - MASTER REGULATOR of glucose homeostasis and adipocyte differentiation
#
# RAF1: Raf-1 Proto-Oncogene - serine/threonine kinase in MAPK pathway
#
# RPL32: Ribosomal Protein L32 - component of ribosome, protein synthesis
#
# SYN2: Synapsin II - synaptic vesicle protein, neurotransmitter release
#
# TIMP4: Tissue Inhibitor of Metalloproteinases 4 - extracellular matrix regulation
#
# TMEM40: Transmembrane Protein 40 - unknown function
#
# TSEN2: tRNA Splicing Endonuclease Subunit 2 - tRNA processing
#
# === CAUSAL ANALYSIS ===
#
# Most likely causal candidates based on biological function:
# 1. PPARG - STRONG CANDIDATE: Master regulator of glucose homeostasis, adipocyte differentiation
#    - Known T2D gene with established causal variants
#    - UniProt confirms: 'Key regulator of glucose homeostasis'
#    - UniProt disease annotation: 'Defects in PPARG can lead to type 2 insulin-resistant diabetes'
#
# 2. RAF1 - MODERATE CANDIDATE: MAPK pathway, insulin signaling
#    - Involved in insulin signaling pathways
#    - Literature shows involvement in glucose regulation
#
# 3. TIMP4 - WEAK CANDIDATE: Associated with diabetic complications
#    - More likely involved in diabetic complications rather than causation
#
# 4. Other genes - UNLIKELY CANDIDATES:
#    - CAND2, MKRN2, RPL32, SYN2, TMEM40, TSEN2: No direct metabolic functions
# </observation>
# ================================== Ai Message ==================================
#
# Let me also check the data lake for any additional evidence:
#
# <execute>
# # Let's check the data lake for any additional evidence
# import pandas as pd
# import os
#
# print("=== Checking Data Lake for Additional Evidence ===")
#
# # Check if we have GWAS catalog data
# gwas_path = "./data/biomni_data/data_lake/gwas_catalog.pkl"
# if os.path.exists(gwas_path):
#     print("Loading GWAS catalog data...")
#     gwas_data = pd.read_pickle(gwas_path)
#     print(f"GWAS catalog shape: {gwas_data.shape}")
#
#     # Look for Type 2 diabetes studies
#     if 'DISEASE/TRAIT' in gwas_data.columns:
#         t2d_studies = gwas_data[gwas_data['DISEASE/TRAIT'].str.contains('diabetes', case=False, na=False)]
#         print(f"Found {len(t2d_studies)} diabetes-related studies")
#
#         # Check for our genes of interest
#         genes_of_interest = ['PPARG', 'RAF1', 'TIMP4']
#         for gene in genes_of_interest:
#             if 'REPORTED GENE(S)' in gwas_data.columns:
#                 gene_studies = gwas_data[gwas_data['REPORTED GENE(S)'].str.contains(gene, case=False, na=False)]
#                 print(f"\n{gene}: Found {len(gene_studies)} studies")
#                 if len(gene_studies) > 0:
#                     diabetes_gene_studies = gene_studies[gene_studies['DISEASE/TRAIT'].str.contains('diabetes', case=False, na=False)]
#                     print(f"  - {len(diabetes_gene_studies)} diabetes-related studies")
# else:
#     print("GWAS catalog data not found in data lake")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>=== Checking Data Lake for Additional Evidence ===
# Loading GWAS catalog data...
# GWAS catalog shape: (622784, 34)
# Found 8950 diabetes-related studies
#
# PPARG: Found 284 studies
#   - 27 diabetes-related studies
#
# RAF1: Found 50 studies
#   - 0 diabetes-related studies
#
# TIMP4: Found 6 studies
#   - 0 diabetes-related studies
# </observation>
# ================================== Ai Message ==================================
#
# Excellent! This provides strong evidence. Let me get more specific details about PPARG's diabetes associations:
#
# <execute>
# # Let's look at the specific PPARG-diabetes studies
# print("=== PPARG Diabetes Studies from GWAS Catalog ===")
#
# if os.path.exists(gwas_path):
#     # Filter for PPARG and diabetes studies
#     pparg_studies = gwas_data[gwas_data['REPORTED GENE(S)'].str.contains('PPARG', case=False, na=False)]
#     pparg_diabetes = pparg_studies[pparg_studies['DISEASE/TRAIT'].str.contains('diabetes', case=False, na=False)]
#
#     print(f"PPARG diabetes studies: {len(pparg_diabetes)}")
#
#     if len(pparg_diabetes) > 0:
#         # Show some key information
#         relevant_cols = ['DISEASE/TRAIT', 'REPORTED GENE(S)', 'STRONGEST SNP-RISK ALLELE', 'P-VALUE']
#         available_cols = [col for col in relevant_cols if col in pparg_diabetes.columns]
#
#         print("\nKey PPARG-diabetes associations:")
#         for idx, row in pparg_diabetes.head(10).iterrows():
#             print(f"\nStudy {idx}:")
#             for col in available_cols:
#                 if pd.notna(row[col]):
#                     print(f"  {col}: {row[col]}")
#
# # Final analysis
# print("\n" + "="*60)
# print("FINAL ANALYSIS - IDENTIFYING THE CAUSAL GENE")
# print("="*60)
#
# print("\nEvidence Summary:")
# print("1. BIOLOGICAL FUNCTION:")
# print("   ✓ PPARG: Master regulator of glucose homeostasis and adipocyte differentiation")
# print("   ✓ Known insulin sensitivity regulator")
#
# print("\n2. DISEASE ASSOCIATION:")
# print("   ✓ UniProt: 'Defects in PPARG can lead to type 2 insulin-resistant diabetes'")
# print("   ✓ Associated with familial partial lipodystrophy (FPLD3) - diabetes-related condition")
#
# print("\n3. GWAS EVIDENCE:")
# print(f"   ✓ PPARG: 27 diabetes-related GWAS studies")
# print("   ✗ RAF1: 0 diabetes-related GWAS studies")
# print("   ✗ TIMP4: 0 diabetes-related GWAS studies")
#
# print("\n4. LITERATURE EVIDENCE:")
# print("   ✓ Multiple PubMed studies linking PPARG to Type 2 diabetes")
# print("   ✓ PPARG is a well-established diabetes susceptibility gene")
#
# print("\nCONCLUSION:")
# print("PPARG is the most likely causal gene for Type 2 diabetes in this locus")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>=== PPARG Diabetes Studies from GWAS Catalog ===
# PPARG diabetes studies: 27
#
# Key PPARG-diabetes associations:
#
# Study 21359:
#   DISEASE/TRAIT: type 2 diabetes
#   REPORTED GENE(S): PPARG
#   STRONGEST SNP-RISK ALLELE: rs1801282-C
#   P-VALUE: 2e-06
#
# Study 21373:
#   DISEASE/TRAIT: type 2 diabetes
#   REPORTED GENE(S): PPARG
#   STRONGEST SNP-RISK ALLELE: rs1801282-C
#   P-VALUE: 2e-06
#
# Study 26863:
#   DISEASE/TRAIT: type 2 diabetes
#   REPORTED GENE(S): PPARG
#   STRONGEST SNP-RISK ALLELE: rs13081389-A
#   P-VALUE: 2e-07
#
# Study 27085:
#   DISEASE/TRAIT: type 2 diabetes
#   REPORTED GENE(S): SYN2, PPARG
#   STRONGEST SNP-RISK ALLELE: rs17036101-G
#   P-VALUE: 2e-07
#
# Study 28215:
#   DISEASE/TRAIT: type 2 diabetes
#   REPORTED GENE(S): PPARG
#   STRONGEST SNP-RISK ALLELE: rs1801282-C
#   P-VALUE: 2e-06
#
# Study 78626:
#   DISEASE/TRAIT: type 2 diabetes
#   REPORTED GENE(S): PPARG
#   STRONGEST SNP-RISK ALLELE: rs3963364-C
#   P-VALUE: 3e-11
#
# Study 99611:
#   DISEASE/TRAIT: type 2 diabetes
#   REPORTED GENE(S): PPARG
#   STRONGEST SNP-RISK ALLELE: rs11709077-G
#   P-VALUE: 2e-36
#
# Study 99612:
#   DISEASE/TRAIT: type 2 diabetes
#   REPORTED GENE(S): PPARG
#   STRONGEST SNP-RISK ALLELE: rs17819328-G
#   P-VALUE: 5e-16
#
# Study 174849:
#   DISEASE/TRAIT: type 2 diabetes
#   REPORTED GENE(S): PPARG
#   STRONGEST SNP-RISK ALLELE: rs11709077-G
#   P-VALUE: 2e-07
#
# Study 174851:
#   DISEASE/TRAIT: type 2 diabetes
#   REPORTED GENE(S): PPARG
#   STRONGEST SNP-RISK ALLELE: rs11709077-G
#   P-VALUE: 1e-08
#
# ============================================================
# FINAL ANALYSIS - IDENTIFYING THE CAUSAL GENE
# ============================================================
#
# Evidence Summary:
# 1. BIOLOGICAL FUNCTION:
#    ✓ PPARG: Master regulator of glucose homeostasis and adipocyte differentiation
#    ✓ Known insulin sensitivity regulator
#
# 2. DISEASE ASSOCIATION:
#    ✓ UniProt: 'Defects in PPARG can lead to type 2 insulin-resistant diabetes'
#    ✓ Associated with familial partial lipodystrophy (FPLD3) - diabetes-related condition
#
# 3. GWAS EVIDENCE:
#    ✓ PPARG: 27 diabetes-related GWAS studies
#    ✗ RAF1: 0 diabetes-related GWAS studies
#    ✗ TIMP4: 0 diabetes-related GWAS studies
#
# 4. LITERATURE EVIDENCE:
#    ✓ Multiple PubMed studies linking PPARG to Type 2 diabetes
#    ✓ PPARG is a well-established diabetes susceptibility gene
#
# CONCLUSION:
# PPARG is the most likely causal gene for Type 2 diabetes in this locus
# </observation>
# ================================== Ai Message ==================================
#
# Perfect! Let me update my checklist and provide the final answer:
#
# ## Updated Plan:
# 1. [✓] Research each gene in the locus to understand their functions and known associations
# 2. [✓] Query databases for Type 2 diabetes associations with each gene
# 3. [✓] Look up literature evidence for each gene's role in diabetes/metabolism
# 4. [✓] Analyze the biological pathways and mechanisms
# 5. [✓] Identify the most likely causal gene based on evidence
#
# Based on my comprehensive analysis, I can now provide a definitive answer about the likely causal gene for Type 2 diabetes in this locus.
#
# <solution>
# PPARG
# </solution>
# Using prompt-based retrieval with the agent's LLM
# ================================ Human Message =================================
#
# Your task is to identify likely causal genes within a locus for a given GWAS phenotype. From the list, provide only the likely causal gene (matching one of the given genes).
# Identify the causal gene.
# GWAS phenotype: Breast carcinoma
# Genes in locus: {AP1B1},{C22orf31},{CCDC117},{CHEK2},{EMID1},{EWSR1},{GAS2L1},{HSCB},{KREMEN1},{RASL10A},{RHBDD3},{TTC28},{XBP1},{ZNRF3}
#
# ================================== Ai Message ==================================
#
# I'll help you identify the likely causal gene for breast carcinoma from the given list. Let me create a systematic plan to analyze these genes and their associations with breast cancer.
#
# ## Plan:
# 1. [ ] Import necessary libraries and set up the analysis environment
# 2. [ ] Query databases for breast cancer gene associations to understand known causal relationships
# 3. [ ] Analyze each gene in the locus for breast cancer associations using multiple databases
# 4. [ ] Cross-reference findings with cancer gene databases (COSMIC, DisGeNET)
# 5. [ ] Prioritize genes based on evidence strength and known cancer mechanisms
# 6. [ ] Provide the most likely causal gene with supporting evidence
#
# Let me start implementing this plan:
#
# <execute>
# # Import necessary libraries
# import pandas as pd
# import json
# from biomni.tool.database import query_cbioportal, query_uniprot, query_opentarget
# from biomni.tool.literature import query_pubmed
#
# print("=== Identifying Causal Gene for Breast Carcinoma ===")
# print("Genes in locus:", ["AP1B1", "C22orf31", "CCDC117", "CHEK2", "EMID1", "EWSR1", "GAS2L1", "HSCB", "KREMEN1", "RASL10A", "RHBDD3", "TTC28", "XBP1", "ZNRF3"])
# print("\nStep 1: Setting up analysis environment - COMPLETED")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>=== Identifying Causal Gene for Breast Carcinoma ===
# Genes in locus: ['AP1B1', 'C22orf31', 'CCDC117', 'CHEK2', 'EMID1', 'EWSR1', 'GAS2L1', 'HSCB', 'KREMEN1', 'RASL10A', 'RHBDD3', 'TTC28', 'XBP1', 'ZNRF3']
#
# Step 1: Setting up analysis environment - COMPLETED
# </observation>
# ================================== Ai Message ==================================
#
# 1. [✓] Import necessary libraries and set up the analysis environment
# 2. [ ] Query databases for breast cancer gene associations to understand known causal relationships
# 3. [ ] Analyze each gene in the locus for breast cancer associations using multiple databases
# 4. [ ] Cross-reference findings with cancer gene databases (COSMIC, DisGeNET)
# 5. [ ] Prioritize genes based on evidence strength and known cancer mechanisms
# 6. [ ] Provide the most likely causal gene with supporting evidence
#
# <execute>
# # Step 2: Query OpenTargets for breast cancer gene associations
# print("Step 2: Querying databases for breast cancer gene associations...")
#
# # Query OpenTargets for breast carcinoma associations
# ot_result = query_opentarget("breast carcinoma gene associations targets", verbose=True)
# print("OpenTargets breast carcinoma associations:")
# print(ot_result)
# print("\n" + "="*50 + "\n")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>Step 2: Querying databases for breast cancer gene associations...
# OpenTargets breast carcinoma associations:
# {'success': True, 'query_info': {'endpoint': 'https://api.platform.opentargets.org/api/v4/graphql', 'method': 'POST', 'description': 'OpenTargets Platform GraphQL query'}, 'result': {'data': {'disease': {'id': 'EFO_0000305', 'name': 'breast carcinoma', 'associatedTargets': {'count': 13250, 'rows': [{'score': 0.8907951897625013, 'target': {'id': 'ENSG00000139618', 'approvedSymbol': 'BRCA2', 'approvedName': 'BRCA2 DNA repair associated'}}, {'score': 0.875089088449842, 'target': {'id': 'ENSG00000012048', 'approvedSymbol': 'BRCA1', 'approvedName': 'BRCA1 DNA repair associated'}}, {'score': 0.8564819576532825, 'target': {'id': 'ENSG00000121879', 'approvedSymbol': 'PIK3CA', 'approvedName': 'phosphatidylinositol-4,5-bisphosphate 3-kinase catalytic subunit alpha'}}, {'score': 0.8553144108781923, 'target': {'id': 'ENSG00000083093', 'approvedSymbol': 'PALB2', 'approvedName': 'partner and localizer of BRCA2'}}, {'score': 0.8549032351892958, 'target': {'id': 'ENSG00000141510', 'approvedSymbol': 'TP53', 'approvedName': 'tumor protein p53'}}, {'score': 0.8302724872062685, 'target': {'id': 'ENSG00000039068', 'approvedSymbol': 'CDH1', 'approvedName': 'cadherin 1'}}, {'score': 0.8297896827612408, 'target': {'id': 'ENSG00000108384', 'approvedSymbol': 'RAD51C', 'approvedName': 'RAD51 paralog C'}}, {'score': 0.8270465496286421, 'target': {'id': 'ENSG00000183765', 'approvedSymbol': 'CHEK2', 'approvedName': 'checkpoint kinase 2'}}, {'score': 0.8220130465164739, 'target': {'id': 'ENSG00000091831', 'approvedSymbol': 'ESR1', 'approvedName': 'estrogen receptor 1'}}, {'score': 0.8205297012513401, 'target': {'id': 'ENSG00000141736', 'approvedSymbol': 'ERBB2', 'approvedName': 'erb-b2 receptor tyrosine kinase 2'}}, {'score': 0.8192723960203657, 'target': {'id': 'ENSG00000142208', 'approvedSymbol': 'AKT1', 'approvedName': 'AKT serine/threonine kinase 1'}}, {'score': 0.8095933056637292, 'target': {'id': 'ENSG00000149311', 'approvedSymbol': 'ATM', 'approvedName': 'ATM serine/threonine kinase'}}, {'score': 0.7965910516468819, 'target': {'id': 'ENSG00000136492', 'approvedSymbol': 'BRIP1', 'approvedName': 'BRCA1 interacting DNA helicase 1'}}, {'score': 0.7922269303025677, 'target': {'id': 'ENSG00000185379', 'approvedSymbol': 'RAD51D', 'approvedName': 'RAD51 paralog D'}}, {'score': 0.7746595339137897, 'target': {'id': 'ENSG00000171862', 'approvedSymbol': 'PTEN', 'approvedName': 'phosphatase and tensin homolog'}}, {'score': 0.7682967516841268, 'target': {'id': 'ENSG00000066468', 'approvedSymbol': 'FGFR2', 'approvedName': 'fibroblast growth factor receptor 2'}}, {'score': 0.7634043706574714, 'target': {'id': 'ENSG00000095015', 'approvedSymbol': 'MAP3K1', 'approvedName': 'mitogen-activated protein kinase kinase kinase 1'}}, {'score': 0.7504377432234882, 'target': {'id': 'ENSG00000138376', 'approvedSymbol': 'BARD1', 'approvedName': 'BRCA1 associated RING domain 1'}}, {'score': 0.7502586919715275, 'target': {'id': 'ENSG00000107485', 'approvedSymbol': 'GATA3', 'approvedName': 'GATA binding protein 3'}}, {'score': 0.7469710478800868, 'target': {'id': 'ENSG00000135111', 'approvedSymbol': 'TBX3', 'approvedName': 'T-box transcription factor 3'}}]}}}}}
#
# ==================================================
#
# </observation>
# ================================== Ai Message ==================================
#
# <execute>
# # Step 3: Check each gene in our locus for breast cancer associations
# print("Step 3: Analyzing each gene in the locus for breast cancer associations...")
#
# genes_in_locus = ["AP1B1", "C22orf31", "CCDC117", "CHEK2", "EMID1", "EWSR1", "GAS2L1", "HSCB", "KREMEN1", "RASL10A", "RHBDD3", "TTC28", "XBP1", "ZNRF3"]
#
# # From the OpenTargets result, I can see CHEK2 is already in the top breast cancer associated genes (score: 0.8270465496286421)
# # Let me verify this and check other genes in our locus
#
# print("CHEK2 found in OpenTargets top breast cancer genes with high score: 0.827")
# print("\nNow checking other genes in our locus...")
#
# # Check a few key genes from our locus
# for gene in ["CHEK2", "EWSR1", "XBP1", "ZNRF3"]:
#     print(f"\nChecking {gene}...")
#     result = query_opentarget(f"{gene} breast carcinoma association", verbose=False)
#     if result.get('success'):
#         print(f"{gene} query successful")
#     else:
#         print(f"{gene} query failed")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>Step 3: Analyzing each gene in the locus for breast cancer associations...
# CHEK2 found in OpenTargets top breast cancer genes with high score: 0.827
#
# Now checking other genes in our locus...
#
# Checking CHEK2...
# CHEK2 query successful
#
# Checking EWSR1...
# EWSR1 query successful
#
# Checking XBP1...
# XBP1 query successful
#
# Checking ZNRF3...
# ZNRF3 query successful
# </observation>
# ================================== Ai Message ==================================
#
# <execute>
# # Let me check the COSMIC cancer gene census data from our data lake
# print("Step 4: Cross-referencing with cancer gene databases...")
#
# # Load COSMIC Cancer Gene Census data
# cosmic_path = "./data/biomni_data/data_lake/Cosmic_CancerGeneCensus_v101_GRCh38.csv"
# try:
#     cosmic_df = pd.read_csv(cosmic_path)
#     print("COSMIC Cancer Gene Census loaded successfully")
#     print(f"Total genes in COSMIC: {len(cosmic_df)}")
#
#     # Check which genes from our locus are in COSMIC
#     our_genes = ["AP1B1", "C22orf31", "CCDC117", "CHEK2", "EMID1", "EWSR1", "GAS2L1", "HSCB", "KREMEN1", "RASL10A", "RHBDD3", "TTC28", "XBP1", "ZNRF3"]
#
#     # Check gene symbols in COSMIC
#     cosmic_genes_in_locus = []
#     for gene in our_genes:
#         if gene in cosmic_df['Gene Symbol'].values:
#             cosmic_genes_in_locus.append(gene)
#             gene_info = cosmic_df[cosmic_df['Gene Symbol'] == gene].iloc[0]
#             print(f"\n{gene} found in COSMIC:")
#             print(f"  - Tumour Types: {gene_info.get('Tumour Types(Somatic)', 'N/A')}")
#             print(f"  - Role in Cancer: {gene_info.get('Role in Cancer', 'N/A')}")
#             print(f"  - Mutation Types: {gene_info.get('Mutation Types', 'N/A')}")
#
#     print(f"\nGenes from our locus in COSMIC Cancer Gene Census: {cosmic_genes_in_locus}")
#
# except Exception as e:
#     print(f"Error loading COSMIC data: {e}")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>Step 4: Cross-referencing with cancer gene databases...
# COSMIC Cancer Gene Census loaded successfully
# Total genes in COSMIC: 753
# Error loading COSMIC data: 'Gene Symbol'
# </observation>
# ================================== Ai Message ==================================
#
# <execute>
# # Let me check the column names in COSMIC data
# try:
#     cosmic_df = pd.read_csv("./data/biomni_data/data_lake/Cosmic_CancerGeneCensus_v101_GRCh38.csv")
#     print("COSMIC columns:", list(cosmic_df.columns))
#     print("\nFirst few rows:")
#     print(cosmic_df.head())
#
# except Exception as e:
#     print(f"Error: {e}")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>COSMIC columns: ['GENE_SYMBOL', 'NAME', 'COSMIC_GENE_ID', 'CHROMOSOME', 'GENOME_START', 'GENOME_STOP', 'CHR_BAND', 'SOMATIC', 'GERMLINE', 'TUMOUR_TYPES_SOMATIC', 'TUMOUR_TYPES_GERMLINE', 'CANCER_SYNDROME', 'TISSUE_TYPE', 'MOLECULAR_GENETICS', 'ROLE_IN_CANCER', 'MUTATION_TYPES', 'TRANSLOCATION_PARTNER', 'OTHER_GERMLINE_MUT', 'OTHER_SYNDROME', 'TIER', 'SYNONYMS']
#
# First few rows:
#   GENE_SYMBOL                                               NAME  \
# 0        A1CF                     APOBEC1 complementation factor
# 1        ABI1                                   abl interactor 1
# 2        ABL1  ABL proto-oncogene 1, non-receptor tyrosine ki...
# 3        ABL2  ABL proto-oncogene 2, non-receptor tyrosine ki...
# 4       ACKR3                      atypical chemokine receptor 3
#
#   COSMIC_GENE_ID CHROMOSOME  GENOME_START  GENOME_STOP  CHR_BAND SOMATIC  \
# 0      COSG68236         10    50799409.0   50885675.0  10q11.23       y
# 1     COSG100962         10    26746593.0   26861087.0   10p12.1       y
# 2     COSG106650          9   130713946.0  130887675.0   9q34.12       y
# 3      COSG93778          1   179099327.0  179229684.0    1q25.2       y
# 4      COSG97311          2   236567787.0  236582358.0    2q37.3       y
#
#   GERMLINE TUMOUR_TYPES_SOMATIC  ... CANCER_SYNDROME TISSUE_TYPE  \
# 0        n             melanoma  ...             NaN           E
# 1        n                  AML  ...             NaN           L
# ...
# ================================== Ai Message ==================================
#
# Great! Now let me check the GWAS catalog data for additional evidence:
#
# <execute>
# # Check GWAS catalog data
# print("Step 10: Analyzing GWAS catalog data...")
#
# gwas_files = [f for f in files if 'gwas_catalog' in f.lower()]
# if gwas_files:
#     print(f"Loading GWAS catalog data from {gwas_files[0]}...")
#
#     try:
#         import pickle
#         with open(os.path.join(data_lake_path, gwas_files[0]), 'rb') as f:
#             gwas_data = pickle.load(f)
#
#         print(f"GWAS data type: {type(gwas_data)}")
#
#         if isinstance(gwas_data, dict):
#             print(f"GWAS data keys: {list(gwas_data.keys())[:10]}")
#         elif isinstance(gwas_data, list) and len(gwas_data) > 0:
#             print(f"GWAS data first entry keys: {list(gwas_data[0].keys()) if isinstance(gwas_data[0], dict) else 'Not a dict'}")
#
#         # Try to find diabetes-related entries
#         diabetes_entries = []
#
#         if isinstance(gwas_data, list):
#             for entry in gwas_data[:1000]:  # Check first 1000 entries
#                 if isinstance(entry, dict):
#                     # Look for diabetes in various fields
#                     for key, value in entry.items():
#                         if isinstance(value, str) and 'diabetes' in value.lower():
#                             diabetes_entries.append(entry)
#                             break
#
#         print(f"Found {len(diabetes_entries)} diabetes-related GWAS entries")
#
#         # Check if any of our genes appear in diabetes GWAS
#         gwas_gene_evidence = {}
#
#         for entry in diabetes_entries[:50]:  # Check first 50 diabetes entries
#             entry_str = str(entry).lower()
#             for gene in genes:
#                 if gene.lower() in entry_str:
#                     if gene not in gwas_gene_evidence:
#                         gwas_gene_evidence[gene] = []
#                     gwas_gene_evidence[gene].append(entry)
#
#         print(f"\nGWAS evidence for our genes:")
#         for gene, evidence in gwas_gene_evidence.items():
#             print(f"  {gene}: {len(evidence)} GWAS entries")
#
#     except Exception as e:
#         print(f"Error loading GWAS data: {e}")
#
# else:
#     print("No GWAS catalog files found")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>Step 10: Analyzing GWAS catalog data...
# Loading GWAS catalog data from gwas_catalog.pkl...
# GWAS data type: <class 'pandas.core.frame.DataFrame'>
# Found 0 diabetes-related GWAS entries
#
# GWAS evidence for our genes:
# </observation>
# ================================== Ai Message ==================================
#
# Let me examine the GWAS data structure more carefully:
#
# <execute>
# # Let's examine the GWAS DataFrame more carefully
# print("Step 11: Detailed GWAS catalog analysis...")
#
# try:
#     import pickle
#     with open(os.path.join(data_lake_path, "gwas_catalog.pkl"), 'rb') as f:
#         gwas_df = pickle.load(f)
#
#     print(f"GWAS DataFrame shape: {gwas_df.shape}")
#     print(f"GWAS DataFrame columns: {list(gwas_df.columns)}")
#
#     # Show first few rows
#     print("\nFirst few rows:")
#     print(gwas_df.head())
#
#     # Look for diabetes-related traits
#     trait_cols = [col for col in gwas_df.columns if 'trait' in col.lower() or 'disease' in col.lower() or 'phenotype' in col.lower()]
#     print(f"\nTrait-related columns: {trait_cols}")
#
#     if trait_cols:
#         trait_col = trait_cols[0]
#         diabetes_studies = gwas_df[gwas_df[trait_col].str.contains('diabetes', case=False, na=False)]
#         print(f"\nFound {len(diabetes_studies)} diabetes-related studies")
#
#         if len(diabetes_studies) > 0:
#             print("Diabetes studies:")
#             for idx, row in diabetes_studies.head(5).iterrows():
#                 print(f"  - {row[trait_col]}")
#
#             # Look for gene columns
#             gene_cols = [col for col in gwas_df.columns if 'gene' in col.lower()]
#             print(f"\nGene-related columns: {gene_cols}")
#
#             if gene_cols:
#                 gene_col = gene_cols[0]
#
#                 # Check our genes in diabetes studies
#                 for gene in genes:
#                     gene_diabetes_studies = diabetes_studies[diabetes_studies[gene_col].str.contains(gene, case=False, na=False)]
#                     if not gene_diabetes_studies.empty:
#                         print(f"\n*** {gene} found in {len(gene_diabetes_studies)} diabetes GWAS studies ***")
#                         for idx, row in gene_diabetes_studies.head(3).iterrows():
#                             print(f"  Study: {row[trait_col]}")
#                             print(f"  Gene: {row[gene_col]}")
#                             if 'pvalue' in gwas_df.columns:
#                                 print(f"  P-value: {row.get('pvalue', 'N/A')}")
#                     else:
#                         print(f"  {gene}: No diabetes GWAS associations found")
#
# except Exception as e:
#     print(f"Error analyzing GWAS data: {e}")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>Step 11: Detailed GWAS catalog analysis...
# GWAS DataFrame shape: (622784, 34)
# GWAS DataFrame columns: ['DATE ADDED TO CATALOG', 'PUBMEDID', 'FIRST AUTHOR', 'DATE', 'JOURNAL', 'LINK', 'STUDY', 'DISEASE/TRAIT', 'INITIAL SAMPLE SIZE', 'REPLICATION SAMPLE SIZE', 'REGION', 'CHR_ID', 'CHR_POS', 'REPORTED GENE(S)', 'MAPPED_GENE', 'UPSTREAM_GENE_ID', 'DOWNSTREAM_GENE_ID', 'SNP_GENE_IDS', 'UPSTREAM_GENE_DISTANCE', 'DOWNSTREAM_GENE_DISTANCE', 'STRONGEST SNP-RISK ALLELE', 'SNPS', 'MERGED', 'SNP_ID_CURRENT', 'CONTEXT', 'INTERGENIC', 'RISK ALLELE FREQUENCY', 'P-VALUE', 'PVALUE_MLOG', 'P-VALUE (TEXT)', 'OR or BETA', '95% CI (TEXT)', 'PLATFORM [SNPS PASSING QC]', 'CNV']
#
# First few rows:
#   DATE ADDED TO CATALOG  PUBMEDID FIRST AUTHOR        DATE    JOURNAL  \
# 0            2018-07-30  27618447  Surendran P  2016-10-01  Nat Genet
# 1            2018-07-30  27618447  Surendran P  2016-10-01  Nat Genet
# 2            2018-07-30  27618447  Surendran P  2016-10-01  Nat Genet
# 3            2018-07-30  27618447  Surendran P  2016-10-01  Nat Genet
# 4            2018-07-30  27618447  Surendran P  2016-10-01  Nat Genet
#
#                                    LINK  \
# 0  www.ncbi.nlm.nih.gov/pubmed/27618447
# 1  www.ncbi.nlm.nih.gov/pubmed/27618447
# 2  www.ncbi.nlm.nih.gov/pubmed/27618447
# 3  www.ncbi.nlm.nih.gov/pubmed/27618447
# 4  www.ncbi.nlm.nih.gov/pubmed/27618447
#
#                                                STUDY            DISEASE/TRAIT  \
# 0  Trans-ancestry meta-analyses identify rare and...  systolic blood pressure
# 1  Trans-ancestry meta-analyses identify rare and...  systolic blood pressure
# 2  Trans-ancestry meta-analyses identify rare and...  systolic blood pressure
# 3  Trans-ancestry meta-analyses identify rare and...  systolic blood pressure
# 4  Trans-ancestry meta-analyses identify rare and...  systolic blood pressure
#
#                                  INITIAL SAMPLE SIZE  \
# 0  up to 165,276 European ancestry individuals, u...
# 1  up to 165,276 European ancestry individuals, u...
# 2  up to 165,276 European ancestry individuals, u...
# 3  up to 165,276 European ancestry individuals, u...
# 4  up to 165,276 European ancestry individuals, u...
#
#                              REPLICATION SAMPLE SIZE  ...             CONTEXT  \
# 0  up to 125,713 European ancestry individuals, u...  ...      intron_variant
# 1  up to 125,713 European ancestry individuals, u...  ...    missense_variant
# 2  up to 125,713 European ancestry individuals, u...  ...  intergenic_variant
# 3  up to 125,713 European ancestry individuals, u...  ...      intron_variant
# 4  up to 125,713 European ancestry individuals, u...  ...      intron_variant
#
#   INTERGENIC RISK ALLELE FREQUENCY       P-VALUE PVALUE_MLOG P-VALUE (TEXT)  \
# 0        0.0                0.5261  8.000000e-09    8.096910            NaN
# 1        0.0                0.0603  1.000000e-07    7.000000            NaN
# 2        1.0                0.4102  7.000000e-23   22.154902            NaN
# 3        1.0                0.3797  4.000000e-08    7.397940            NaN
# 4        0.0                0.7305  3.000000e-07    6.522879            NaN
#
#   OR or BETA  95% CI (TEXT)  PLATFORM [SNPS PASSING QC]  CNV
# 0     0.0196  mmHg decrease           Illumina [242296]    N
# 1     0.0420  mmHg decrease           Illumina [242296]    N
# 2     0.0327  mmHg decrease           Illumina [242296]    N
# 3     0.0194  mmHg decrease           Illumina [242296]    N
# 4     0.0191  mmHg decrease           Illumina [242296]    N
#
# [5 rows x 34 columns]
#
# Trait-related columns: ['DISEASE/TRAIT']
#
# Found 8950 diabetes-related studies
# Diabetes studies:
#   - stimulated c-peptide levels in type i diabetes
#   - stimulated c-peptide levels in type i diabetes
#   - random c-peptide levels in type i diabetes
#   - c-peptide levels in type i diabetes
#   - c-peptide levels in type i diabetes
#
# Gene-related columns: ['REPORTED GENE(S)', 'MAPPED_GENE', 'UPSTREAM_GENE_ID', 'DOWNSTREAM_GENE_ID', 'SNP_GENE_IDS', 'UPSTREAM_GENE_DISTANCE', 'DOWNSTREAM_GENE_DISTANCE']
#   BMP6: No diabetes GWAS associations found
#   CAGE1: No diabetes GWAS associations found
#   DSP: No diabetes GWAS associations found
#   RIOK1: No diabetes GWAS associations found
#
# *** RREB1 found in 16 diabetes GWAS studies ***
#   Study: type 2 diabetes
#   Gene: SSR1, RREB1
#   Study: type 2 diabetes
#   Gene: RREB1
#   Study: type 2 diabetes
#   Gene: RREB1
#   SNRNP48: No diabetes GWAS associations found
#
# *** SSR1 found in 5 diabetes GWAS studies ***
#   Study: type 2 diabetes
#   Gene: SSR1, RREB1
#   Study: type 2 diabetes
#   Gene: RREB1, SSR1
#   Study: type 2 diabetes
#   Gene: SSR1, RREB1
# </observation>
# ================================== Ai Message ==================================
#
# Perfect! Now I have strong evidence. Let me summarize and analyze the findings:
#
# <execute>
# # Final analysis and summary
# print("=== FINAL CAUSAL GENE ANALYSIS ===")
# print()
#
# # Summary of evidence found
# evidence_summary = {
#     'BMP6': {
#         'DisGeNET_diabetes_associations': 3,
#         'GWAS_diabetes_studies': 0,
#         'diseases': ['Diabetes Mellitus, Insulin-Dependent', 'Diabetes', 'Diabetes Mellitus']
#     },
#     'CAGE1': {
#         'DisGeNET_diabetes_associations': 0,
#         'GWAS_diabetes_studies': 0,
#         'diseases': []
#     },
#     'DSP': {
#         'DisGeNET_diabetes_associations': 0,
#         'GWAS_diabetes_studies': 0,
#         'diseases': []
#     },
#     'RIOK1': {
#         'DisGeNET_diabetes_associations': 0,
#         'GWAS_diabetes_studies': 0,
#         'diseases': []
#     },
#     'RREB1': {
#         'DisGeNET_diabetes_associations': 1,
#         'GWAS_diabetes_studies': 16,
#         'diseases': ['Diabetes Mellitus, Non-Insulin-Dependent']
#     },
#     'SNRNP48': {
#         'DisGeNET_diabetes_associations': 0,
#         'GWAS_diabetes_studies': 0,
#         'diseases': []
#     },
#     'SSR1': {
#         'DisGeNET_diabetes_associations': 1,
#         'GWAS_diabetes_studies': 5,
#         'diseases': ['Diabetes Mellitus, Non-Insulin-Dependent']
#     }
# }
#
# print("EVIDENCE SUMMARY:")
# print("=" * 60)
#
# total_scores = {}
# for gene, evidence in evidence_summary.items():
#     # Calculate total evidence score
#     score = evidence['DisGeNET_diabetes_associations'] + (evidence['GWAS_diabetes_studies'] * 2)  # Weight GWAS higher
#     total_scores[gene] = score
#
#     print(f"{gene}:")
#     print(f"  DisGeNET associations: {evidence['DisGeNET_diabetes_associations']}")
#     print(f"  GWAS studies: {evidence['GWAS_diabetes_studies']}")
#     print(f"  Associated diseases: {evidence['diseases']}")
#     print(f"  TOTAL EVIDENCE SCORE: {score}")
#     print()
#
# # Rank genes by evidence
# ranked_genes = sorted(total_scores.items(), key=lambda x: x[1], reverse=True)
#
# print("RANKING BY EVIDENCE:")
# print("=" * 60)
# for i, (gene, score) in enumerate(ranked_genes, 1):
#     print(f"{i}. {gene} (Score: {score})")
#
# print()
# print("KEY FINDINGS:")
# print("=" * 60)
# print("• RREB1 has the strongest evidence with 16 GWAS studies for Type 2 diabetes")
# print("• RREB1 is associated with 'Diabetes Mellitus, Non-Insulin-Dependent' (Type 2 diabetes)")
# print("• SSR1 also shows evidence with 5 GWAS studies for Type 2 diabetes")
# print("• Both RREB1 and SSR1 appear together in several GWAS studies")
# print("• BMP6 has some DisGeNET associations but no GWAS evidence")
# print("• Other genes (CAGE1, DSP, RIOK1, SNRNP48) show no diabetes associations")
#
# print()
# print("CONCLUSION:")
# print("=" * 60)
# print("Based on the comprehensive analysis of DisGeNET and GWAS catalog data:")
# print("RREB1 is the most likely causal gene for Type 2 diabetes in this locus")
# print("- 16 independent GWAS studies associate RREB1 with Type 2 diabetes")
# print("- Consistent association with Non-Insulin-Dependent Diabetes Mellitus")
# print("- RREB1 is a transcription factor that could plausibly affect diabetes pathways")
# </execute>
# ================================== Ai Message ==================================
#
# <observation>=== FINAL CAUSAL GENE ANALYSIS ===
#
# EVIDENCE SUMMARY:
# ============================================================
# BMP6:
#   DisGeNET associations: 3
#   GWAS studies: 0
#   Associated diseases: ['Diabetes Mellitus, Insulin-Dependent', 'Diabetes', 'Diabetes Mellitus']
#   TOTAL EVIDENCE SCORE: 3
#
# CAGE1:
#   DisGeNET associations: 0
#   GWAS studies: 0
#   Associated diseases: []
#   TOTAL EVIDENCE SCORE: 0
#
# DSP:
#   DisGeNET associations: 0
#   GWAS studies: 0
#   Associated diseases: []
#   TOTAL EVIDENCE SCORE: 0
#
# RIOK1:
#   DisGeNET associations: 0
#   GWAS studies: 0
#   Associated diseases: []
#   TOTAL EVIDENCE SCORE: 0
#
# RREB1:
#   DisGeNET associations: 1
#   GWAS studies: 16
#   Associated diseases: ['Diabetes Mellitus, Non-Insulin-Dependent']
#   TOTAL EVIDENCE SCORE: 33
#
# SNRNP48:
#   DisGeNET associations: 0
#   GWAS studies: 0
#   Associated diseases: []
#   TOTAL EVIDENCE SCORE: 0
#
# SSR1:
#   DisGeNET associations: 1
#   GWAS studies: 5
#   Associated diseases: ['Diabetes Mellitus, Non-Insulin-Dependent']
#   TOTAL EVIDENCE SCORE: 11
#
# RANKING BY EVIDENCE:
# ============================================================
# 1. RREB1 (Score: 33)
# 2. SSR1 (Score: 11)
# 3. BMP6 (Score: 3)
# 4. CAGE1 (Score: 0)
# 5. DSP (Score: 0)
# 6. RIOK1 (Score: 0)
# 7. SNRNP48 (Score: 0)
#
# KEY FINDINGS:
# ============================================================
# • RREB1 has the strongest evidence with 16 GWAS studies for Type 2 diabetes
# • RREB1 is associated with 'Diabetes Mellitus, Non-Insulin-Dependent' (Type 2 diabetes)
# • SSR1 also shows evidence with 5 GWAS studies for Type 2 diabetes
# • Both RREB1 and SSR1 appear together in several GWAS studies
# • BMP6 has some DisGeNET associations but no GWAS evidence
# • Other genes (CAGE1, DSP, RIOK1, SNRNP48) show no diabetes associations
#
# CONCLUSION:
# ============================================================
# Based on the comprehensive analysis of DisGeNET and GWAS catalog data:
# RREB1 is the most likely causal gene for Type 2 diabetes in this locus
# - 16 independent GWAS studies associate RREB1 with Type 2 diabetes
# - Consistent association with Non-Insulin-Dependent Diabetes Mellitus
# - RREB1 is a transcription factor that could plausibly affect diabetes pathways
# </observation>
# ================================== Ai Message ==================================
#
# 2. [✓] Query literature databases for each gene's association with Type 2 diabetes (completed with data lake analysis)
# 3. [✓] Query biological databases for functional information about each gene (completed with OpenTargets and UniProt)
# 4. [✓] Analyze GWAS catalog data for Type 2 diabetes associations (completed)
# 5. [✓] Evaluate the evidence for each gene and identify the most likely causal candidate (completed)
#
# <solution>
# RREB1
# </solution>
# [('gwas_causal_gene_opentargets', 619, '\\nPPARG\\n'),
#  ('gwas_causal_gene_opentargets', 760, '\\nCHEK2\\n'),
#  ('gwas_causal_gene_opentargets', 645, '\\nRREB1\\n')]

# %%
def clean_answer(answer): 
    """
    Clean answer by removing all whitespace, newlines, and escaped newlines
    """
    if answer is None:
        return ""
    
    answer_str = str(answer)
    
    # Remove escaped newlines (\\n)
    answer_str = answer_str.replace('\\n', '')
    
    # Remove actual newlines (\n)
    answer_str = answer_str.replace('\n', '')
    
    # Remove all whitespace
    answer_str = answer_str.strip()
    
    return answer_str

def calculate_accuracy(evaluations, eval_df):
    """
    Calculate accuracy by matching evaluation results with ground truth.
    """
    correct = 0
    total = len(evaluations)
    
    print("=" * 60)
    print("EVALUATION RESULTS")
    print("=" * 60)
    
    for task_name, task_instance_id, user_answer in evaluations:
        # Find ground truth
        ground_truth_row = eval_df[eval_df['task_instance_id'] == task_instance_id]
        
        if len(ground_truth_row) > 0:
            ground_truth = ground_truth_row.iloc[0]['answer']
            
            # Clean both answers
            user_clean = clean_answer(user_answer)
            truth_clean = clean_answer(ground_truth)
            
            # Case-insensitive comparison
            is_correct = user_clean.upper() == truth_clean.upper()
            
            if is_correct:
                correct += 1
                status = "✓ CORRECT"
            else:
                status = "✗ INCORRECT"
            
            print(f"\nTask Instance ID: {task_instance_id}")
            print(f"  User Answer (raw):    '{user_answer}'")
            print(f"  User Answer (clean):  '{user_clean}'")
            print(f"  Ground Truth (clean): '{truth_clean}'")
            print(f"  Status: {status}")
        else:
            print(f"\n⚠ Task Instance ID {task_instance_id}: No ground truth found")
    
    accuracy = correct / total if total > 0 else 0
    
    print("\n" + "=" * 60)
    print(f"Total: {total} | Correct: {correct} | Accuracy: {accuracy:.2%}")
    print("=" * 60)
    
    return {
        'total': total,
        'correct': correct,
        'accuracy': accuracy
    }

# Your evaluation results
evaluations = [
    ('gwas_causal_gene_opentargets', 619, 'PPARG'),
    ('gwas_causal_gene_opentargets', 760, '\\nCHEK2\\n'),
    ('gwas_causal_gene_opentargets', 645, '\\nRREB1\\n')
]

# Load eval DataFrame
eval_df = pd.read_parquet('biomni_eval1_dataset.parquet')

# Calculate accuracy
results = calculate_accuracy(evaluations, eval_df)
# Out:
# ============================================================
# EVALUATION RESULTS
# ============================================================
#
# Task Instance ID: 619
#   User Answer (raw):    'PPARG'
#   User Answer (clean):  'PPARG'
#   Ground Truth (clean): 'PPARG'
#   Status: ✓ CORRECT
#
# Task Instance ID: 760
#   User Answer (raw):    '\nCHEK2\n'
#   User Answer (clean):  'CHEK2'
#   Ground Truth (clean): 'CHEK2'
#   Status: ✓ CORRECT
#
# Task Instance ID: 645
#   User Answer (raw):    '\nRREB1\n'
#   User Answer (clean):  'RREB1'
#   Ground Truth (clean): 'RREB1'
#   Status: ✓ CORRECT
#
# ============================================================
# Total: 3 | Correct: 3 | Accuracy: 100.00%
# ============================================================

# %%
results
# Out:
# {'total': 3, 'correct': 3, 'accuracy': 1.0}
